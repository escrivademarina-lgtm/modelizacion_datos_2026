# %%
import pandas as pd
# Out:
# Running cells with 'modelizacion-datos-2026 (Python 3.12.1)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Marina Escriva/OneDrive/Documentos/GitHub/modelizacion_datos_2026/.venv/Scripts/python.exe" -m pip install ipykernel -U --force-reinstall'
